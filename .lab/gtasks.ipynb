# %%
from skyant.datager import GTasks

# %%
class Cc(GTasks):
    id: str
    er: int


x = Cc(id='asd', er=234)

# %%
x.send_gtasks(
    url='https://www.google.com',
    queue='waw',
    location=GTasks.Location.US_CENTRAL1,
    method=GTasks.Method.PUT
)

# %%
from google import auth
cr = auth.default()[0]

# %%
auth.__dict__
# Out:
# {'__name__': 'google.auth',
#  '__doc__': 'Google Auth Library for Python.',
#  '__package__': 'google.auth',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f744fd05ab0>,
#  '__spec__': ModuleSpec(name='google.auth', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f744fd05ab0>, origin='/home/gitpod/.local/lib/python3.10/site-packages/google/auth/__init__.py', submodule_search_locations=['/home/gitpod/.local/lib/python3.10/site-packages/google/auth']),
#  '__path__': ['/home/gitpod/.local/lib/python3.10/site-packages/google/auth'],
#  '__file__': '/home/gitpod/.local/lib/python3.10/site-packages/google/auth/__init__.py',
#  '__cached__': '/home/gitpod/.local/lib/python3.10/site-packages/google/auth/__pycache__/__init__.cpython-310.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
# ...
